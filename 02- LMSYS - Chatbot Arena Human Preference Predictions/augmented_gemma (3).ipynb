# %%
# !python script_2.py --ver 3 --max_len 3096 --batch_size 32 --grad_acc_steps 1 --warmup_steps 20 --save_steps 300 --eval_batch_size 8 --extra_train "lmsys-additional-33k-labelled-conversations/lmsys-33k-deduplicated.csv" --extra_train2 "lmsys-additional-33k-labelled-conversations/hf52k_deduplicated.csv" --freeze_layers 0 --lora_r 256 --lora_dropout 0.05 --lr 1.5e-5 --n_splits 10 --fold_idx 0 --epochs 1
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/hamidme/.cache/huggingface/token
# Login successful
# 2024-07-31 17:12:55,250 [INFO] === Parameter Settings ===
# 2024-07-31 17:12:55,250 [INFO]   VER: 3
# 2024-07-31 17:12:55,250 [INFO]   max_length: 3096
# 2024-07-31 17:12:55,250 [INFO]   n_splits: 10
# 2024-07-31 17:12:55,250 [INFO]   fold_idx: 0
# 2024-07-31 17:12:55,250 [INFO]   per_device_train_batch_size: 32
# 2024-07-31 17:12:55,250 [INFO]   gradient_accumulation_steps: 1
# 2024-07-31 17:12:55,250 [INFO]   per_device_eval_batch_size: 8
# 2024-07-31 17:12:55,250 [INFO]   n_epochs: 1
# 2024-07-31 17:12:55,250 [INFO]   freeze_layers: 0
# 2024-07-31 17:12:55,250 [INFO]   lr: 1.5e-05
# 2024-07-31 17:12:55,250 [INFO]   warmup_steps: 20
# ...
